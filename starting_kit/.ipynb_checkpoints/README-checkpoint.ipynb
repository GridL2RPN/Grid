# %% [markdown]
# <div style="background:#FFFFAA">
# <img src="./logo.jpg", width=150, ALIGN="left", border=20>
# <h1>L2RPN Starting Kit </h1>
#
# <br>This code was tested with <br>
# Python 3.6.6 |Anaconda custom (64-bit)| (default, Nov 2018, 11:07:29) (https://anaconda.org/)<br>
# <i> Adapted for Chalab by Isabelle Guyon from original code of Balázs Kégl</i> <br>
# <a href="http://www.datascience-paris-saclay.fr">Paris Saclay Center for Data Science (CDS)</a>
# </center>
# <p>
# ALL INFORMATION, SOFTWARE, DOCUMENTATION, AND DATA ARE PROVIDED "AS-IS". The CDS, CHALEARN, AND/OR OTHER ORGANIZERS OR CODE AUTHORS DISCLAIM ANY EXPRESSED OR IMPLIED WARRANTIES, INCLUDING, BUT NOT LIMITED TO, THE IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR ANY PARTICULAR PURPOSE, AND THE WARRANTY OF NON-INFRIGEMENT OF ANY THIRD PARTY'S INTELLECTUAL PROPERTY RIGHTS. IN NO EVENT SHALL AUTHORS AND ORGANIZERS BE LIABLE FOR ANY SPECIAL,
# INDIRECT OR CONSEQUENTIAL DAMAGES OR ANY DAMAGES WHATSOEVER ARISING OUT OF OR IN CONNECTION WITH THE USE OR PERFORMANCE OF SOFTWARE, DOCUMENTS, MATERIALS, PUBLICATIONS, OR INFORMATION MADE AVAILABLE FOR THE CHALLENGE.
# </div>

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Introduction </h2>
#     <p>
#      <br>
# The goal of this challenge is to use Reinforcement Learning in Power Grid management by designing RL agents to automate the control of the power grid. The dataset used in this challenge is from <a href="https://github.com/MarvinLer/pypownet">pypownet</a>, made by Marvin Lerousseau, it is a simulator that is able to emulate a power grid of any size and electrical properties subject to a set of temporal injections for discretized time-steps.
#
# References and credits: <br>
# Founder of pypownet was Marvin Lerousseau. The competition protocol was designed by Isabelle Guyon. Our mentors are Balthazar Donon and Antoine Marot. Pypownet, 2017. https://github.com/MarvinLer/pypownet. The baseline methods were inspired by work performed by Kimang Khun.
#  <br>
# </div>

# %%
model_dir = 'example_submission/'
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
input_dir = 'public_data/'
output_dir = 'output/'
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir);
path.append(input_dir); path.append(output_dir);
# %matplotlib inline
# Uncomment the next lines to auto-reload libraries (this causes some problem with pickles in Python 3)
# %load_ext autoreload
# %autoreload 2
import seaborn as sns; sns.set()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Step 1: Exploratory data analysis </h1>
# <p>
# We provide data with the starting kit.
#     <br>
# </div>

# %% [markdown]
# ## Electrical grid
# <div >
# <img src="./ExampleGrid.JPG", width=750, ALIGN="left", border=20>
#     <br>
#     <br>
# (courtesy of Marvin Lerousseau)
# </div>

# %% [markdown]
# During the challenge, a grid of 14 substations is given. 20 lines connected the nodes of the network.
#
# For the following example, we take the case where there are 11 loads and 5 prods and particularly the hard level. Furthermore, the information shown are only those of January.

# %%
data_dir = 'public_data/hard'              # Change this to the directory where you put the input data
# !ls $data_dir*
# Out:
# chronics  configuration.yaml  reference_grid.m

# %% [markdown]
# For convenience, we load the data as a "pandas" data frame, so we can use "pandas" to explore the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

loads_p_file = '_N_loads_p.csv'
prods_p_file = '_N_prods_p.csv'
datetimes_file = '_N_datetimes.csv'
maintenance_file = 'maintenance.csv'
hazards_file = 'hazards.csv'
imaps_file = '_N_imaps.csv'
df_loads_p = {}
df_prods_p = {}
df_datetimes = {}
df_maintenance = {}
df_hazards = {} 
i = 0 # chronics id

path = data_dir+'/chronics/'+str(i)+'/'
df_loads_p[str(i)] = pd.read_csv(path+loads_p_file, sep=';')
df_prods_p[str(i)] = pd.read_csv(path+prods_p_file, sep=';')
df_datetimes[str(i)] = pd.read_csv(path+datetimes_file, sep=';')
df_loads_p[str(i)].index = pd.to_datetime(df_datetimes[str(i)]['date'] + ' ' + df_datetimes[str(i)]['time'])
df_prods_p[str(i)].index = pd.to_datetime(df_datetimes[str(i)]['date'] + ' ' + df_datetimes[str(i)]['time'])
df_maintenance[str(i)] = pd.read_csv(path+maintenance_file, sep=';')
df_maintenance[str(i)].index = pd.to_datetime(df_datetimes[str(i)]['date'] + ' ' + df_datetimes[str(i)]['time'])
df_hazards[str(i)] = pd.read_csv(path+hazards_file, sep=';')
df_hazards[str(i)].index = pd.to_datetime(df_datetimes[str(i)]['date'] + ' ' + df_datetimes[str(i)]['time'])
df_imaps = pd.read_csv(path + imaps_file, sep=';')

# %% [markdown]
# ## Loads
#
# The following figure shows the active power of consumptions which represents the amount of demand of active power. This information appears in the \_N\_loads\_p.csv. Note that the power needed is cyclic during the day. In our particular case, the load 3_C151.15 is the one which needs power the most power. The loads for the other levels are pretty similar with a load needing much more power than the others.

# %%
plt.figure(figsize=[15,4])
plt.title('Loads Time Series #'+str(0))
plt.xlabel('Time')
plt.ylabel('Power (MW)')
plt.plot(df_loads_p[str(0)])
plt.legend(list(df_loads_p[str(0)]))
plt.show()

# %% [markdown]
# ## Production
#
# The active power of the productions is shown below. In the easy mode, each one of them is stable contrary to the medium and hard modes where the productions are much more heterogeneous.

# %%
plt.figure(figsize=[15,4])
plt.title('Prods Time Series #'+str(0))
plt.xlabel('Time')
plt.ylabel('Power (MW)')
plt.plot(df_prods_p[str(0)])
plt.legend(list(df_prods_p[str(0)]))
plt.show()

# %% [markdown]
# ## Maintenance
#
# Maintenance exist only for the hard mode. When a maintenance happens for a production, the voltage magnitudes of the associated production is set to 0 in \_N\_prods\_v.csv for a number of timesteps. Here, two maintenances happen in January.

# %%
plt.figure(figsize=[15,4])
plt.title('Maintenance Time Series #'+str(0))
plt.xlabel('Time')
plt.ylabel('Duration of line disconnections (timesteps)')
plt.plot(df_maintenance[str(0)])
plt.show()

# %% [markdown]
# ## Hazard
#
# Again, hazards only happen with the hard mode. They represent external events that break lines from time to time, be it natural hazards or ones related to the network itself.

# %%
plt.figure(figsize=[15,4])
plt.title('Hazards Time Series #'+str(0))
plt.xlabel('Time')
plt.ylabel('Duration of line disconnections (timesteps)')
plt.plot(df_hazards[str(0)])
plt.show()

# %% [markdown]
# <div style="background:#FFFFAA">
# <h1>Step 2: Building an Agent</h1>
# </div>

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Loading data with pypownet</h2>
#     <p>
# We reload the data with the environment class of pypownet
#    <br>
#
# To win, flows in a line have to stay under a threshold. Above this threshold, the line will overheat and after a certain amount of overheating, the line will break. Thermal limits are already defined in pypownet.
# </div>

# %%
import os
import pypownet.environment
import pypownet.runner
data_dir = 'public_data'  
environment = pypownet.environment.RunEnv(parameters_folder=os.path.abspath(data_dir),
                                              game_level="hard",
                                              chronic_looping_mode='natural', start_id=0,
                                              game_over_mode="soft")
# Out:
# Using custom reward signal CustomRewardSignal of file /home/tp-home007/grenoua/projects/Grid/starting_kit/public_data/reward_signal.py
#   ====================================================
#                      GAME PARAMETERS
#   ====================================================
#     loadflow_mode: AC
#     n_timesteps_soft_overflow_is_broken: 10
#     loadflow_backend: pypower
#     max_number_prods_game_over: 3
#     max_seconds_per_timestep: 1.0
#     n_timesteps_consecutive_soft_overflow_breaks: 10
#     max_number_loads_game_over: 6
#     n_timesteps_horizon_maintenance: 48
#     hard_overflow_coefficient: 1.0
#     n_timesteps_hard_overflow_is_broken: 10
#   ====================================================

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Building an agent</h2>
#     <p>
# We provide examples of agent (for reinforcement learning) in the `starting-kit/example_submission` directory. It is a quite stupid agent: it does nothing. Replace it with your own agent.
#     </div>

# %% [markdown]
# ## Do nothing agent
#
# The agent does not take any actions.

# %%
import pypownet.agent
import pypownet.environment


class DoNothingAgent(pypownet.agent.Agent):
    def __init__(self, environment):
        super().__init__(environment)

    def act(self, observation):
        """ Produces an action given an observation of the environment. Takes as argument an observation of the current
        power grid, and returns the chosen action."""
        # Sanity check: an observation is a structured object defined in the environment file.
        assert isinstance(observation, pypownet.environment.Observation)

        action_space = self.environment.action_space

        # Implement your policy here
        # Example of the do-nothing policy that produces no action (i.e. an action that does nothing) each time
        do_nothing_action = action_space.get_do_nothing_action()

        # Sanity check: verify the good overall structure of the returned action; raises exceptions if not valid
        assert action_space.verify_action_shape(do_nothing_action)
        return do_nothing_action

# %%
from example_submission import baseline_agents
# Uncomment the next line to display the code of the DoNothing Agent
#??baseline_agents.DoNothingAgent

# %% [markdown]
# ## RandomLineSwitch agent
# The agent randomly switches the status of one random power line per timestep (if the random line is previously online, switch it off, otherwise switch it on

# %%
from example_submission import baseline_agents
# Uncomment the next line to display the code of the RandomLineSwitch Agent
#??baseline_agents.RandomLineSwitch

# %% [markdown]
# ## RandomNodeSplitting agent
# The agent selects a random switch configuration such that switched elements of the selected substations change the node within the substation on which they are directly wired.

# %%
from example_submission import baseline_agents
# Uncomment the next line to display the code of the RandomNodeSplitting Agent
#??baseline_agents.RandomNodeSplitting

# %% [markdown]
# <div style="background:#FFFFAA">
# an instance of the agent (run the constructor) and attempt to reload a previously saved version from `starting_kit/example_submission/`:
#
# </div>

# %% [markdown]
# ## Scoring the results of an agent
#
# <div style="background:#FFFFAA">
#     <br>
#     <p>
# <b>The metric chosen for your challenge</b> is identified in the "metric.txt" file found in the `scoring_function/` directory. The function "get_metric" searches first for a metric having that name in my_metric.py, then in libscores.py, then in sklearn.metric.
#     <br>
# The aim of a reinforcement learning problem is to maximize the reward function.
#
# When running the agent, two values are given back : the first one is the reward of the last timestep and the second one is the cumulative reward for all the iterations of the run of the agent. The reward indicates if the game is going towards a game over or not.
#
# Specifically, our reward function is composed of 5 subrewards. They describe the proportion of isolated productions, loads, the cost of an action, an indication of the amount of changes between the current grid and the initial grid and lastly information on the lines capacity usage.
#     </div>

# %%
from scoring_program import libscores
from libscores import get_metric
metric_name, scoring_function = get_metric()
print('Using scoring metric:', metric_name)
# Uncomment the next line to display the code of the scoring metric
#??scoring_function
# Out:
# Using scoring metric: reward

# %% [markdown]
# ### Run the Do nothing agent

# %%
import time
start = time.time()
end = time.time()
print(end-start)
# Out:
# 3.9577484130859375e-05

# %%
import logging
import sys
import os
start = time.time()
NUMBER_ITERATIONS = 50 # The number of iterations can be changed

submission_dir = 'example_submission'
sys.path.append(submission_dir)

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
log_path = os.path.abspath(os.path.join(output_dir, 'runner.log'))


open(log_path, 'w').close()
submitted_controler = baseline_agents.DoNothingAgent(environment)
# Instanciate a runner, that will save the run statistics within the log_path file, to be parsed and processed
# by the scoring program
phase_runner = pypownet.runner.Runner(environment, submitted_controler, verbose=True, vverbose=False,
                                      log_filepath=log_path)
phase_runner.ch.setLevel(logging.ERROR)
# Run the planned experiment of this phase with the submitted model
score = phase_runner.loop(iterations=NUMBER_ITERATIONS)
print("cumulative rewards : {}".format(score))
end = time.time()
print(end-start)
# Out:
# cumulative rewards : -11.269334237132291
# 1.17918062210083

# %%
#get the score with the scoring_function
scoring_function(output_dir)
# Out:
# step : 50, cumulative rewards : -11.27

# %% [markdown]
# ### Run the RandomLineSwitch agent

# %%
import logging
import sys
start = time.time()
NUMBER_ITERATIONS = 50

submission_dir = 'example_submission'
sys.path.append(submission_dir)

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
log_path = os.path.abspath(os.path.join(output_dir, 'runner.log'))


open(log_path, 'w').close()
submitted_controler = baseline_agents.RandomLineSwitch(environment)
# Instanciate a runner, that will save the run statistics within the log_path file, to be parsed and processed
# by the scoring program
phase_runner = pypownet.runner.Runner(environment, submitted_controler, verbose=True, vverbose=False,
                                      log_filepath=log_path)
phase_runner.ch.setLevel(logging.ERROR)
# Run the planned experiment of this phase with the submitted model
score = phase_runner.loop(iterations=NUMBER_ITERATIONS)
print("cumulative rewards : {}".format(score))
end = time.time()
print(end-start)
# Out:
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.12 ] = 0.08194981510136856
# Action chosen:  switching status of line 17 ; expected reward 0.0819
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.12 ] = 0.07584368685041433
# Action chosen:  switching status of line 3 ; expected reward 0.0758
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.15 ] = 0.04920417452401463
# Action chosen:  switching status of line 10 ; expected reward 0.0492
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.13 ] = -2.734635850136607
# Action chosen:  switching status of line 16 ; expected reward -2.7346
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.14 ] = -2.7357593561978772
# Action chosen:  switching status of line 0 ; expected reward -2.7358
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.14 ] = -2.736010498554866
# Action chosen:  switching status of line 7 ; expected reward -2.7360
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.36 ] = -2.9584722070464218
# Action chosen:  switching status of line 5 ; expected reward -2.9585
# reward: [ -2.80, -1.40, 0.20, -0.00, -0.36 ] = -4.357622497602583
# Action chosen:  switching status of line 13 ; expected reward -4.3576
# reward: [ -0.00, -1.40, 0.20, -0.00, -0.38 ] = -1.582661698197642
# Action chosen:  switching status of line 16 ; expected reward -1.5827
# reward: [ -0.00, -1.40, 0.20, -0.00, -0.39 ] = -1.5936043585817337
# Action chosen:  switching status of line 7 ; expected reward -1.5936
# reward: [ -2.80, -1.40, 0.20, -0.00, -0.39 ] = -4.3923941281797
# Action chosen:  switching status of line 12 ; expected reward -4.3924
# reward: [ -2.80, -1.40, 0.20, -0.00, -0.38 ] = -4.379966230532344
# Action chosen:  switching status of line 14 ; expected reward -4.3800
# reward: [ -2.80, -1.40, 0.20, -0.00, -0.55 ] = -4.546875634682338
# Action chosen:  switching status of line 18 ; expected reward -4.5469
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.12 ] = 0.07903746965511346
# Action chosen:  switching status of line 10 ; expected reward 0.0790
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.13 ] = 0.07125492607136527
# Action chosen:  switching status of line 3 ; expected reward 0.0713
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.14 ] = 0.06290952682983783
# Action chosen:  switching status of line 1 ; expected reward 0.0629
# reward: [ -0.00, -1.40, 0.20, -0.00, -0.13 ] = -1.3331186561978199
# Action chosen:  switching status of line 0 ; expected reward -1.3331
# reward: [ -0.00, -1.40, 0.20, -0.00, -0.18 ] = -1.3780858084176564
# Action chosen:  switching status of line 18 ; expected reward -1.3781
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.19 ] = 0.011278225800724767
# Action chosen:  switching status of line 0 ; expected reward 0.0113
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.46 ] = -0.25819186519353066
# Action chosen:  switching status of line 5 ; expected reward -0.2582
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.46 ] = -0.25959586342997315
# Action chosen:  switching status of line 7 ; expected reward -0.2596
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.57 ] = -0.3692986413396218
# Action chosen:  switching status of line 16 ; expected reward -0.3693
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.48 ] = -0.2791647369597062
# Action chosen:  switching status of line 16 ; expected reward -0.2792
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.49 ] = -0.28880284232223674
# Action chosen:  switching status of line 14 ; expected reward -0.2888
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.37 ] = -2.972035066181894
# Action chosen:  switching status of line 19 ; expected reward -2.9720
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.25 ] = -2.8478903843935415
# Action chosen:  switching status of line 3 ; expected reward -2.8479
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.34 ] = -2.9394385381899033
# Action chosen:  switching status of line 8 ; expected reward -2.9394
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.34 ] = -2.944306411445807
# Action chosen:  switching status of line 14 ; expected reward -2.9443
# reward: [ -2.80, -1.40, 0.20, -0.00, -0.35 ] = -4.349102169144359
# Action chosen:  switching status of line 13 ; expected reward -4.3491
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.35 ] = -2.95469214296129
# Action chosen:  switching status of line 13 ; expected reward -2.9547
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.28 ] = -2.8763554080569227
# Action chosen:  switching status of line 5 ; expected reward -2.8764
# reward: [ -2.80, -0.00, 0.20, -0.00, -0.26 ] = -2.8585598035424087
# Action chosen:  switching status of line 1 ; expected reward -2.8586
# reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
# Action chosen:  switching status of line 12 ; expected reward -13.8000
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.15 ] = 0.05424713405021303
# Action chosen:  switching status of line 15 ; expected reward 0.0542
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.14 ] = 0.05600945910485461
# Action chosen:  switching status of line 4 ; expected reward 0.0560
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.20 ] = 0.0006329091496344308
# Action chosen:  switching status of line 0 ; expected reward 0.0006
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.20 ] = -0.0025179213672612277
# Action chosen:  switching status of line 14 ; expected reward -0.0025
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.25 ] = -0.04674372827217535
# Action chosen:  switching status of line 17 ; expected reward -0.0467
# reward: [ -0.00, -1.40, 0.20, -0.00, -0.16 ] = -1.3619162205786632
# Action chosen:  switching status of line 1 ; expected reward -1.3619
# reward: [ -0.00, -1.40, 0.20, -0.00, -0.18 ] = -1.3758091529056073
# Action chosen:  switching status of line 11 ; expected reward -1.3758
# reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
# Action chosen:  switching status of line 7 ; expected reward -13.8000
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.17 ] = 0.030482674889248135
# Action chosen:  switching status of line 8 ; expected reward 0.0305
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.18 ] = 0.022072851691532613
# Action chosen:  switching status of line 6 ; expected reward 0.0221
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.23 ] = -0.03036785991201421
# Action chosen:  switching status of line 14 ; expected reward -0.0304
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.27 ] = -0.07093784952131854
# Action chosen:  switching status of line 16 ; expected reward -0.0709
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.16 ] = 0.042958442737923874
# Action chosen:  switching status of line 2 ; expected reward 0.0430
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.18 ] = 0.0183171629320609
# Action chosen:  switching status of line 12 ; expected reward 0.0183
# reward: [ -2.80, -1.40, 0.20, -0.00, -0.30 ] = -4.296355989894055
# Action chosen:  switching status of line 5 ; expected reward -4.2964
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.25 ] = -0.05201428796541968
# Action chosen:  switching status of line 2 ; expected reward -0.0520
# reward: [ -0.00, -0.00, 0.20, -0.00, -0.25 ] = -0.05494676724122838
# Action chosen:  switching status of line 14 ; expected reward -0.0549
# cumulative rewards : -123.5868048820456
# 2.084641456604004

# %%
#get the score with the scoring_function
scoring_function(output_dir)
# Out:
# step : 50, cumulative rewards : -72.25

# %% [markdown]
# ### Run the RandomNodeSplitting agent

# %%
import logging
import sys
start = time.time()
NUMBER_ITERATIONS = 50

submission_dir = 'example_submission'
sys.path.append(submission_dir)

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
log_path = os.path.abspath(os.path.join(output_dir, 'runner.log'))


open(log_path, 'w').close()
submitted_controler = baseline_agents.RandomNodeSplitting(environment)
# Instanciate a runner, that will save the run statistics within the log_path file, to be parsed and processed
# by the scoring program
phase_runner = pypownet.runner.Runner(environment, submitted_controler, verbose=True, vverbose=False,
                                      log_filepath=log_path)
phase_runner.ch.setLevel(logging.ERROR)
# Run the planned experiment of this phase with the submitted model
score = phase_runner.loop(iterations=NUMBER_ITERATIONS)
print("cumulative rewards : {}".format(score))
end = time.time()
print(end-start)
# Out:
# reward: [ -0.00, -0.00, 0.30, -0.06, -0.25 ] = -0.014170619899762482
# Action chosen:  change in topo of sub. 1 with switches array([1, 1, 1]) ; expected reward -0.0142
# reward: [ -0.00, -0.00, 0.20, -0.10, -0.30 ] = -0.195877674626141
# Action chosen:  change in topo of sub. 11 with switches array([1, 0, 1]) ; expected reward -0.1959
# reward: [ -0.00, -0.00, 0.20, -0.14, -0.71 ] = -0.6537140008194677
# Action chosen:  change in topo of sub. 4 with switches array([1, 0, 0, 1, 0, 0]) ; expected reward -0.6537
# reward: [ -0.00, -0.00, 0.30, -0.06, -0.13 ] = 0.11079470721489262
# Action chosen:  change in topo of sub. 1 with switches array([1, 1, 1]) ; expected reward 0.1108
# reward: [ -0.00, -0.00, 0.30, -0.12, -0.22 ] = -0.03936493204692876
# Action chosen:  change in topo of sub. 4 with switches array([0, 0, 1, 0, 1, 1]) ; expected reward -0.0394
# reward: [ -0.00, -0.00, 0.30, -0.18, -0.22 ] = -0.09942890961000653
# Action chosen:  change in topo of sub. 7 with switches array([1, 1, 1]) ; expected reward -0.0994
# reward: [ -0.00, -0.00, 0.30, -0.24, -0.22 ] = -0.1614385203566797
# Action chosen:  change in topo of sub. 2 with switches array([1, 0, 0, 1, 1, 0]) ; expected reward -0.1614
# reward: [ -0.00, -0.00, 0.10, -0.22, -0.39 ] = -0.514346000732591
# Action chosen:  change in topo of sub. 1 with switches array([0, 0, 1]) ; expected reward -0.5143
# reward: [ -0.00, -0.00, 0.10, -0.24, -0.40 ] = -0.5381187354504322
# Action chosen:  change in topo of sub. 11 with switches array([0, 1, 0]) ; expected reward -0.5381
# reward: [ -0.00, -0.00, 0.00, -0.24, -0.39 ] = -0.6291419904378515
# Action chosen:  change in topo of sub. 11 with switches array([0, 0, 0]) ; expected reward -0.6291
# reward: [ -2.80, -0.00, 0.20, -0.28, -0.35 ] = -3.226197249438814
# Action chosen:  change in topo of sub. 12 with switches array([0, 1, 1]) ; expected reward -3.2262
# reward: [ -2.80, -0.00, 0.20, -0.32, -0.57 ] = -3.490050012735766
# Action chosen:  change in topo of sub. 5 with switches array([0, 1, 0, 1, 0]) ; expected reward -3.4901
# reward: [ -0.00, -0.00, 0.20, -0.04, -0.12 ] = 0.03714592965693196
# Action chosen:  change in topo of sub. 13 with switches array([1, 0, 1, 0]) ; expected reward 0.0371
# reward: [ -0.00, -0.00, 0.00, -0.04, -0.12 ] = -0.16269527542322984
# Action chosen:  change in topo of sub. 14 with switches array([0, 0, 0]) ; expected reward -0.1627
# reward: [ -0.00, -0.00, 0.20, -0.08, -0.15 ] = -0.029629972927229922
# Action chosen:  change in topo of sub. 5 with switches array([0, 0, 1, 1, 0]) ; expected reward -0.0296
# reward: [ -0.00, -0.00, 0.00, -0.08, -0.15 ] = -0.22932141119354388
# Action chosen:  change in topo of sub. 8 with switches array([0, 0]) ; expected reward -0.2293
# reward: [ -0.00, -0.00, 0.10, -0.10, -0.17 ] = -0.17091434730706478
# Action chosen:  change in topo of sub. 1 with switches array([0, 1, 0]) ; expected reward -0.1709
# reward: [ -2.80, -0.00, 0.10, -0.12, -0.10 ] = -2.924419310543528
# Action chosen:  change in topo of sub. 10 with switches array([1, 0, 0]) ; expected reward -2.9244
# reward: [ -2.80, -0.00, 0.20, -0.16, -0.13 ] = -2.89060579287596
# Action chosen:  change in topo of sub. 9 with switches array([0, 0, 1, 0, 1]) ; expected reward -2.8906
# reward: [ -2.80, -0.00, 0.20, -0.16, -0.23 ] = -2.9868627391311473
# Action chosen:  change in topo of sub. 13 with switches array([0, 1, 1, 0]) ; expected reward -2.9869
# reward: [ -0.00, -1.40, 0.50, -0.10, -0.31 ] = -1.3051426103888304
# Action chosen:  change in topo of sub. 6 with switches array([0, 1, 1, 1, 1, 1]) ; expected reward -1.3051
# reward: [ -0.00, -1.40, 0.40, -0.18, -0.50 ] = -1.6833155087042209
# Action chosen:  change in topo of sub. 5 with switches array([1, 0, 1, 1, 1]) ; expected reward -1.6833
# reward: [ -0.00, -1.40, 0.20, -0.22, -1.95 ] = -3.367526682316373
# Action chosen:  change in topo of sub. 3 with switches array([1, 0, 0, 1]) ; expected reward -3.3675
# reward: [ -0.00, -0.00, 0.30, -0.06, -0.13 ] = 0.1147797366825008
# Action chosen:  change in topo of sub. 1 with switches array([1, 1, 1]) ; expected reward 0.1148
# reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.0283244989052312
# Action chosen:  change in topo of sub. 14 with switches array([1, 0, 1]) ; expected reward -0.0283
# reward: [ -0.00, -0.00, 0.10, -0.12, -0.19 ] = -0.20829383371518168
# Action chosen:  change in topo of sub. 3 with switches array([0, 0, 1, 0]) ; expected reward -0.2083
# reward: [ -0.00, -0.00, 0.20, -0.16, -0.19 ] = -0.152728785261619
# Action chosen:  change in topo of sub. 7 with switches array([1, 1, 0]) ; expected reward -0.1527
# reward: [ -2.80, -0.00, 0.20, -0.20, -0.19 ] = -2.9874055973424483
# Action chosen:  change in topo of sub. 11 with switches array([0, 1, 1]) ; expected reward -2.9874
# reward: [ -2.80, -0.00, 0.10, -0.22, -0.19 ] = -3.1067007900664527
# Action chosen:  change in topo of sub. 9 with switches array([0, 0, 0, 1, 0]) ; expected reward -3.1067
# reward: [ -5.60, -1.40, 0.30, -0.24, -0.55 ] = -7.486332821566952
# Action chosen:  change in topo of sub. 3 with switches array([1, 1, 1, 0]) ; expected reward -7.4863
# reward: [ -8.40, -1.40, 0.10, -0.26, -0.52 ] = -10.47882107007089
# Action chosen:  change in topo of sub. 13 with switches array([1, 0, 0, 0]) ; expected reward -10.4788
# reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
# Action chosen:  change in topo of sub. 4 with switches array([1, 0, 0, 1, 0, 0]) ; expected reward -13.8000
# reward: [ -0.00, -0.00, 0.30, -0.06, -0.28 ] = -0.036375656858711414
# Action chosen:  change in topo of sub. 9 with switches array([0, 0, 1, 1, 1]) ; expected reward -0.0364
# reward: [ -0.00, -0.00, 0.30, -0.06, -0.14 ] = 0.09821141335705905
# Action chosen:  change in topo of sub. 5 with switches array([1, 1, 1, 0, 0]) ; expected reward 0.0982
# reward: [ -0.00, -0.00, 0.20, -0.10, -0.14 ] = -0.04459055481406271
# Action chosen:  change in topo of sub. 13 with switches array([0, 1, 0, 1]) ; expected reward -0.0446
# /home/tp-home007/grenoua/projects/ENV/lib/python3.5/site-packages/scipy-1.1.0-py3.5-linux-x86_64.egg/scipy/sparse/linalg/dsolve/linsolve.py:192: MatrixRankWarning: Matrix is exactly singular
#   warn("Matrix is exactly singular", MatrixRankWarning)
# reward: [ -0.00, -0.00, 0.10, -0.12, -0.16 ] = -0.17829256502492208
# Action chosen:  change in topo of sub. 14 with switches array([0, 0, 1]) ; expected reward -0.1783
# reward: [ -0.00, -0.00, 0.20, -0.16, -0.19 ] = -0.14806973374497848
# Action chosen:  change in topo of sub. 4 with switches array([0, 0, 1, 0, 1, 0]) ; expected reward -0.1481
# reward: [ -0.00, -0.00, 0.20, -0.20, -0.18 ] = -0.1765280133563285
# Action chosen:  change in topo of sub. 14 with switches array([1, 1, 0]) ; expected reward -0.1765
# reward: [ -0.00, -0.00, 0.30, -0.26, -0.21 ] = -0.17487156972629567
# Action chosen:  change in topo of sub. 9 with switches array([1, 0, 0, 1, 1]) ; expected reward -0.1749
# reward: [ -0.00, -0.00, 0.20, -0.26, -0.23 ] = -0.28598251653544804
# Action chosen:  change in topo of sub. 5 with switches array([0, 1, 0, 0, 1]) ; expected reward -0.2860
# reward: [ -0.00, -0.00, 0.20, -0.30, -0.54 ] = -0.6371466014316393
# Action chosen:  change in topo of sub. 12 with switches array([1, 1, 0]) ; expected reward -0.6371
# reward: [ -0.00, -0.00, 0.10, -0.02, -0.13 ] = -0.051593756830426815
# Action chosen:  change in topo of sub. 14 with switches array([0, 1, 0]) ; expected reward -0.0516
# reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.0043297896819201875
# Action chosen:  change in topo of sub. 4 with switches array([1, 0, 0, 0, 1, 0]) ; expected reward -0.0043
# reward: [ -0.00, -0.00, 0.20, -0.10, -0.21 ] = -0.10876833805217179
# Action chosen:  change in topo of sub. 5 with switches array([1, 0, 1, 0, 0]) ; expected reward -0.1088
# reward: [ -0.00, -0.00, 0.30, -0.12, -0.51 ] = -0.3301291141088287
# Action chosen:  change in topo of sub. 5 with switches array([1, 0, 0, 1, 1]) ; expected reward -0.3301
# reward: [ -0.00, -0.00, 0.10, -0.14, -0.57 ] = -0.6096492444709476
# Action chosen:  change in topo of sub. 7 with switches array([0, 1, 0]) ; expected reward -0.6096
# reward: [ -0.00, -0.00, 0.30, -0.16, -0.61 ] = -0.4725178560008628
# Action chosen:  change in topo of sub. 4 with switches array([1, 0, 1, 0, 0, 1]) ; expected reward -0.4725
# reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
# Action chosen:  change in topo of sub. 9 with switches array([1, 0, 1, 0, 0]) ; expected reward -13.8000
# reward: [ -0.00, -0.00, 0.20, -0.04, -0.16 ] = 0.004777605352419251
# Action chosen:  change in topo of sub. 1 with switches array([1, 1, 0]) ; expected reward 0.0048
# reward: [ -0.00, -0.00, 0.10, -0.06, -0.16 ] = -0.12431622835606479
# Action chosen:  change in topo of sub. 3 with switches array([0, 0, 0, 1]) ; expected reward -0.1243
# cumulative rewards : -156.7158811706581
# 2.2239773273468018

# %%
#get the score with the scoring_function
scoring_function(output_dir)
# Out:
# step : 50, cumulative rewards : -182.65

# %% [markdown]
# <div style="background:#FFFFAA">
#     <b> Save the best agent </b> it should be a class Submission and save in "example_submission/submission.py".  Uncomment the line <i>%%writefile example_submission/submission.py to save the agent. </i>
# </div>

# %%
#%%writefile example_submission/submission.py
import pypownet.agent
import pypownet.environment

class Submission(pypownet.agent.Agent):
    def __init__(self, environment):
        super().__init__(environment)

    def act(self, observation):
        """ Produces an action given an observation of the environment. Takes as argument an observation of the current
        power grid, and returns the chosen action."""
        # Sanity check: an observation is a structured object defined in the environment file.
        assert isinstance(observation, pypownet.environment.Observation)

        action_space = self.environment.action_space

        # Implement your policy here
        # Example of the do-nothing policy that produces no action (i.e. an action that does nothing) each time
        do_nothing_action = action_space.get_do_nothing_action()

        # Sanity check: verify the good overall structure of the returned action; raises exceptions if not valid
        assert action_space.verify_action_shape(do_nothing_action)
        return do_nothing_action

# %% [markdown]
# <div style="background:#FFFFAA">
# <h1> Step 3: Making a submission </h1>
#
# <h2> Unit testing </h2>
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>submission.py</code> in the <code>starting_kit/example_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.
# <br>
# Keep the sample code simple.
# </div>

# %%
# !python $problem_dir/ingestion.py $input_dir $input_dir/res $problem_dir $model_dir
# Out:
# Traceback (most recent call last):
#   File "ingestion_program//ingestion.py", line 3, in <module>
#     import pypownet.environment
# ImportError: No module named pypownet.environment

# %% [markdown]
# <div style="background:#FFFFAA">
# Also test the scoring program:
#     </div>

# %%
scoring_output_dir = 'output'
# !python $score_dir/evaluate.py $input_dir $scoring_output_dir
# Out:
# Traceback (most recent call last):
#   File "scoring_program//evaluate.py", line 4, in <module>
#     import numpy as np
# ImportError: No module named numpy

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Preparing the submission </h1>
#
# Zip the contents of `sample_code_submission/` (without the directory), or download the challenge public_data and run the command in the previous cell, after replacing sample_data by public_data.
# Then zip the contents of `sample_result_submission/` (without the directory).
# <b><span style="color:red">Do NOT zip the data with your submissions</span></b>.

# %%
import datetime 
from data_io import zipdir
the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
sample_code_submission = 'sample_code_submission_' + the_date + '.zip' 
zipdir(sample_code_submission, model_dir) 
print("Submit one of these files:\n" + sample_code_submission + "\n")
# Out:
# Submit one of these files:
# sample_code_submission_19-02-15-18-44.zip

# %%
import logging
import sys
import time
start = time.time()
NUMBER_ITERATIONS = 50 # The number of iterations can be changed

submission_dir = 'example_submission'
sys.path.append(submission_dir)

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
log_path = os.path.abspath(os.path.join(output_dir, 'runner.log'))


open(log_path, 'w').close()
submitted_controler = baseline_agents.GreedySearch(environment)
# Instanciate a runner, that will save the run statistics within the log_path file, to be parsed and processed
# by the scoring program
phase_runner = pypownet.runner.Runner(environment, submitted_controler, verbose=True, vverbose=False,
                                      log_filepath=log_path)
phase_runner.ch.setLevel(logging.ERROR)
# Run the planned experiment of this phase with the submitted model
score = phase_runner.loop(iterations=NUMBER_ITERATIONS)
print("cumulative rewards : {}".format(score))
end = time.time()
print(end-start)
# Out:
# Storing actions at saved_actions.csv
#  Simulation with no action; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13794427405017778
#  Simulation with switching status of line 0; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.047196619702058434
#  Simulation with switching status of line 1; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04436309499937846
#  Simulation with switching status of line 2; reward: [ -0.00, -0.00, 0.20, -0.02, -0.15 ] = 0.02765598475220188
#  Simulation with switching status of line 3; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05017152503683664
#  Simulation with switching status of line 4; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06368398794190418
#  Simulation with switching status of line 5; reward: [ -0.00, -0.00, 0.20, -0.02, -0.22 ] = -0.03984857152554694
#  Simulation with switching status of line 6; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.051621416173369794
#  Simulation with switching status of line 7; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06107554829340245
#  Simulation with switching status of line 8; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.046375549962332674
#  Simulation with switching status of line 9; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.062055725949822255
#  Simulation with switching status of line 10; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04129132392474788
#  Simulation with switching status of line 11; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05283618574216292
#  Simulation with switching status of line 12; reward: [ -0.00, -0.00, 0.20, -0.02, -0.15 ] = 0.030726491145318918
#  Simulation with switching status of line 13; reward: [ -0.00, -1.40, 0.20, -0.02, -0.12 ] = -1.3379442740501777
#  Simulation with switching status of line 14; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06107554829340256
#  Simulation with switching status of line 15; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.061955759767452864
#  Simulation with switching status of line 16; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.05979326322265316
#  Simulation with switching status of line 17; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04255319334955188
#  Simulation with switching status of line 18; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.05995249879491338
#  Simulation with switching status of line 19; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.039915274851496596
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13794427405017778
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.59 ] = -0.5334141001299205
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.88 ] = -0.8218369005219662
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 1]; reward: [ -2.80, -1.40, 0.20, -0.06, -0.79 ] = -4.849116901276189
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.04, -0.37 ] = -3.1094023061780343
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.67 ] = -0.5255413019674918
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.92 ] = -0.7764330201099658
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 1]; reward: [ -0.00, -1.40, 0.30, -0.08, -0.67 ] = -1.8526663669954138
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13794427405017778
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.06795079328422257
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.056089610472311154
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.016497235425555812
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.06978816632753776
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02306236868751843
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.002744597123918835
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.11 ] = -2.6924656975419206
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.00, -0.12 ] = -0.018241089956828424
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05395332966894245
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06347797037956875
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.13828862521737817
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04426977569807938
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.14338067804230473
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.14 ] = 0.11902956060829722
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 1]; reward: [ -0.00, -0.00, 0.40, -0.06, -0.12 ] = 0.215033310659687
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13794427405017778
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05892445170659746
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.07362445003766738
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 1]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.06020673677734686
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.016486170351695945
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.004881013264548928
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.23 ] = -0.012554178334181487
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05804424023254722
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02022499206381506
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.014964214791872432
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.19 ] = 0.027451992814299553
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.01220974895593388
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.12 ] = 0.09713954696016602
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.14 ] = 0.07907954768495845
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 1]; reward: [ -2.80, -0.00, 0.40, -0.10, -0.08 ] = -2.5771561140865065
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13794427405017778
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.06004750120508658
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.0787086760752519
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.21 ] = -0.0667366341890287
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.08008472514850348
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.020076171310905097
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02037334753386394
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.10 ] = -2.6834952218132195
# Action chosen:  change in topo of sub. 5 with switches [0, 1, 1, 1, 1] ; expected reward 0.2150
#  Simulation with no action; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18496668934031302
#  Simulation with switching status of line 0; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.0028433098314383787
#  Simulation with switching status of line 1; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.00042633015903306704
#  Simulation with switching status of line 2; reward: [ -0.00, -0.00, 0.20, -0.06, -0.16 ] = -0.01567973365309877
#  Simulation with switching status of line 3; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.00017229059309312178
#  Simulation with switching status of line 4; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.0181191905741436
#  Simulation with switching status of line 5; reward: [ -0.00, -0.00, 0.20, -0.06, -0.23 ] = -0.09346738831845763
#  Simulation with switching status of line 6; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.001978827254205673
#  Simulation with switching status of line 7; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.013413016941869027
#  Simulation with switching status of line 8; reward: [ -0.00, -0.00, 0.20, -0.06, -0.15 ] = -0.01088698091236362
#  Simulation with switching status of line 9; reward: [ -2.80, -0.00, 0.20, -0.06, -0.11 ] = -2.772164423473458
#  Simulation with switching status of line 10; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.00042276048386419296
#  Simulation with switching status of line 11; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.007384810276936105
#  Simulation with switching status of line 12; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.004071790521044449
#  Simulation with switching status of line 13; reward: [ -0.00, -1.40, 0.20, -0.06, -0.12 ] = -1.384966689340313
#  Simulation with switching status of line 14; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.013413016941869194
#  Simulation with switching status of line 15; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.011480320884228123
#  Simulation with switching status of line 16; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.014937443560053776
#  Simulation with switching status of line 17; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.004834981230645435
#  Simulation with switching status of line 18; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.01363696003810333
#  Simulation with switching status of line 19; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0038398359682718375
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18496668934031302
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.60 ] = -0.5775325698709796
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.91 ] = -0.890300219483228
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 1]; reward: [ -2.80, -1.40, 0.20, -0.10, -0.81 ] = -4.910283746000066
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.08, -0.52 ] = -3.3034193944413537
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.76 ] = -0.6602165445943544
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -1.18 ] = -1.082654321806771
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 1]; reward: [ -0.00, -1.40, 0.30, -0.12, -0.94 ] = -2.15779127744731
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18496668934031302
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.08097043939170284
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05661932195769533
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04426977569807938
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.061711374782621904
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06347797037956875
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05395332966894245
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.00, -0.12 ] = 0.18175891004317163
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.08, -0.11 ] = -2.8924656975419203
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.002744597123918835
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02306236868751843
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.13 ] = 0.1302118336724623
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.016497235425555812
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.14391038952768892
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.13 ] = 0.1320492067157775
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 1]; reward: [ -0.00, -0.00, 0.40, -0.02, -0.12 ] = 0.26205572594982224
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18496668934031302
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.13 ] = -0.10658698305813082
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.15 ] = -0.13088698091236367
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 1]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.13 ] = -0.10506255643994618
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.029244766786530596
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.14 ] = -0.04273281229481629
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.27 ] = -0.09110961675964285
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.13 ] = -0.10851967911577194
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.12 ] = -0.024052358680994063
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.03224908619365732
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.22 ] = -0.042709889910876764
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 0]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.12 ] = 0.05859701578029404
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.14 ] = 0.04077701618083718
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 1]; reward: [ -2.80, -0.00, 0.40, -0.14, -0.07 ] = -2.6108064629599776
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18496668934031302
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.13 ] = -0.10636303996189651
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.14 ] = -0.1204227604838639
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.19 ] = -0.08985207284337149
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.14 ] = -0.11616016403172814
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.025371554395515306
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.0279279282639405
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.12, -0.10 ] = -2.7192748652615766
# Action chosen:  change in topo of sub. 5 with switches [0, 1, 1, 1, 1] ; expected reward 0.2621
#  Simulation with no action; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13761228063487282
#  Simulation with switching status of line 0; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.047651853386333515
#  Simulation with switching status of line 1; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.0448043083099762
#  Simulation with switching status of line 2; reward: [ -0.00, -0.00, 0.20, -0.02, -0.15 ] = 0.027918445622236582
#  Simulation with switching status of line 3; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05057173241712934
#  Simulation with switching status of line 4; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06399757814836646
#  Simulation with switching status of line 5; reward: [ -0.00, -0.00, 0.20, -0.02, -0.22 ] = -0.03939632913432947
#  Simulation with switching status of line 6; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05203123295104109
#  Simulation with switching status of line 7; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06141685454372399
#  Simulation with switching status of line 8; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.04685652340288815
#  Simulation with switching status of line 9; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.062387719365127325
#  Simulation with switching status of line 10; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04165192317863145
#  Simulation with switching status of line 11; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05318010317477245
#  Simulation with switching status of line 12; reward: [ -0.00, -0.00, 0.20, -0.02, -0.15 ] = 0.030974409298912764
#  Simulation with switching status of line 13; reward: [ -0.00, -1.40, 0.20, -0.02, -0.12 ] = -1.3376122806348727
#  Simulation with switching status of line 14; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06141685454372427
#  Simulation with switching status of line 15; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06232491870027214
#  Simulation with switching status of line 16; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06010318161244034
#  Simulation with switching status of line 17; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.042819111572128116
#  Simulation with switching status of line 18; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.060290579992442694
#  Simulation with switching status of line 19; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04032119361289885
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13761228063487282
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.59 ] = -0.5277511510140982
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.87 ] = -0.8138042846264946
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 1]; reward: [ -2.80, -1.40, 0.20, -0.06, -0.78 ] = -4.842784657027545
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.04, -0.37 ] = -3.1094023061780343
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.67 ] = -0.5253439691763192
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.92 ] = -0.7758840626086059
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 1]; reward: [ -0.00, -1.40, 0.30, -0.08, -0.67 ] = -1.851859542519684
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13761228063487282
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.06752299370843073
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.055790535957973335
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.016884544465743154
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.06946228821516848
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02336637685217495
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0031017068762229927
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.11 ] = -2.692172590766472
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.00, -0.12 ] = -0.017922426770339853
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05429711986203306
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06378947405034496
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.13860969208092191
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04471347597183703
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.1437023279944712
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.14 ] = 0.11951397276079306
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 1]; reward: [ -0.00, -0.00, 0.40, -0.06, -0.12 ] = 0.21544497736327367
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13761228063487282
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05858314545627575
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.07314347659711196
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 1]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.059896818387559704
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.016831661291237865
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.005296975027644341
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.23 ] = -0.011451248889637167
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.057675081299727864
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.020496043208306045
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.015245109396880965
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.19 ] = 0.02791791179663622
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.01151801718510051
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.12 ] = 0.09730851921562228
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.14 ] = 0.0792648533427305
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 1]; reward: [ -2.80, -0.00, 0.40, -0.10, -0.08 ] = -2.5771293104026483
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13761228063487282
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.059709420007557225
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.07834807682136832
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.21 ] = -0.06625871515169682
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.07967880638710093
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02041633237735148
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02069801780744923
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.10 ] = -2.683354323996393
# Action chosen:  change in topo of sub. 5 with switches [0, 1, 1, 1, 1] ; expected reward 0.2154
#  Simulation with no action; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18400038736057087
#  Simulation with switching status of line 0; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.0013313518082799514
#  Simulation with switching status of line 1; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0009352580080098927
#  Simulation with switching status of line 2; reward: [ -0.00, -0.00, 0.20, -0.06, -0.16 ] = -0.015102925496772529
#  Simulation with switching status of line 3; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0010550192376496403
#  Simulation with switching status of line 4; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.01900295241176725
#  Simulation with switching status of line 5; reward: [ -0.00, -0.00, 0.20, -0.06, -0.23 ] = -0.09240068125692111
#  Simulation with switching status of line 6; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.000647508302177302
#  Simulation with switching status of line 7; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.014403234459923947
#  Simulation with switching status of line 8; reward: [ -0.00, -0.00, 0.20, -0.06, -0.15 ] = -0.00953809538041786
#  Simulation with switching status of line 9; reward: [ -2.80, -0.00, 0.20, -0.06, -0.11 ] = -2.7714979792935117
#  Simulation with switching status of line 10; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.000614209716795544
#  Simulation with switching status of line 11; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.008385377431766178
#  Simulation with switching status of line 12; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.0033052041109332964
#  Simulation with switching status of line 13; reward: [ -0.00, -1.40, 0.20, -0.06, -0.12 ] = -1.3840003873605708
#  Simulation with switching status of line 14; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.014403234459924391
#  Simulation with switching status of line 15; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.012686253845014456
#  Simulation with switching status of line 16; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.015890030678745004
#  Simulation with switching status of line 17; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.005655567847703824
#  Simulation with switching status of line 18; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.014619300090726067
#  Simulation with switching status of line 19; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0046687051404812885
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18400038736057087
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.60 ] = -0.5798530746304097
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.91 ] = -0.892911370781693
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 1]; reward: [ -2.80, -1.40, 0.20, -0.10, -0.81 ] = -4.911442751104615
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.08, -0.52 ] = -3.3014957358160477
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.76 ] = -0.6584620054704169
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -1.18 ] = -1.078908722133238
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 1]; reward: [ -0.00, -1.40, 0.30, -0.12, -0.93 ] = -2.1526449629132034
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18400038736057087
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.07970157247372453
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05590949299291866
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.04545059399211418
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.06093557300760483
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.0641531772826041
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.054800764710257216
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.00, -0.12 ] = 0.18247852537025952
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.08, -0.11 ] = -2.8918413463629524
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.003662336859196036
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02372938128424279
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.13 ] = 0.13104194416777765
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.017468636666027396
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.14455142895129336
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.13 ] = 0.13312896090081766
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 1]; reward: [ -0.00, -0.00, 0.40, -0.02, -0.12 ] = 0.26280592211941434
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18400038736057087
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.13 ] = -0.10559676554007559
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.15 ] = -0.12953809538041788
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 1]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.12 ] = -0.10410996932125502
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.028266577645313956
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.14 ] = -0.04165542671159733
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.27 ] = -0.08859214336795607
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.13 ] = -0.10731374615498586
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.12 ] = -0.023216392530410218
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.031351687916933435
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.22 ] = -0.0412893010145364
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 0]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.12 ] = 0.05932189894204121
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.14 ] = 0.0414552325137931
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 1]; reward: [ -2.80, -0.00, 0.40, -0.14, -0.07 ] = -2.6107386272905986
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18400038736057087
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.13 ] = -0.10538069990927383
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.14 ] = -0.11938579028320408
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.19 ] = -0.08851548423980973
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.14 ] = -0.11533129485951844
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.12 ] = -0.02444784851180125
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.13 ] = -0.02687076144169906
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.12, -0.10 ] = -2.7189892632848522
# Action chosen:  change in topo of sub. 5 with switches [0, 1, 1, 1, 1] ; expected reward 0.2628
#  Simulation with no action; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13667960652518765
#  Simulation with switching status of line 0; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.04932749947527354
#  Simulation with switching status of line 1; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.04635981478432569
#  Simulation with switching status of line 2; reward: [ -0.00, -0.00, 0.20, -0.02, -0.15 ] = 0.02816936238848511
#  Simulation with switching status of line 3; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05182690045873148
#  Simulation with switching status of line 4; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06482087577462398
#  Simulation with switching status of line 5; reward: [ -0.00, -0.00, 0.20, -0.02, -0.22 ] = -0.038504835692156236
#  Simulation with switching status of line 6; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05337726279097141
#  Simulation with switching status of line 7; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06237720041955283
#  Simulation with switching status of line 8; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.048231870491472595
#  Simulation with switching status of line 9; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06332039347481244
#  Simulation with switching status of line 10; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04257582716245223
#  Simulation with switching status of line 11; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.05412134618768352
#  Simulation with switching status of line 12; reward: [ -0.00, -0.00, 0.20, -0.02, -0.15 ] = 0.03191727464255273
#  Simulation with switching status of line 13; reward: [ -0.00, -1.40, 0.20, -0.02, -0.12 ] = -1.3366796065251878
#  Simulation with switching status of line 14; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06237720041955304
#  Simulation with switching status of line 15; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06330722244361195
#  Simulation with switching status of line 16; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.060907746043923516
#  Simulation with switching status of line 17; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.043372715310980775
#  Simulation with switching status of line 18; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.061228660056572834
#  Simulation with switching status of line 19; reward: [ -0.00, -0.00, 0.20, -0.02, -0.14 ] = 0.04085100730828767
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13667960652518765
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.58 ] = -0.515615618817979
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.86 ] = -0.7961596533031109
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 1]; reward: [ -2.80, -1.40, 0.20, -0.06, -0.77 ] = -4.828455144879423
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.04, -0.37 ] = -3.1085372225482018
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.67 ] = -0.525214656300834
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.91 ] = -0.773174650344383
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 1]; reward: [ -0.00, -1.40, 0.30, -0.08, -0.67 ] = -1.8466154073080228
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13667960652518765
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.0661146037218687
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05501477149653173
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.018147050967547332
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.0683855557024299
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02418758153887285
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.004293288841616116
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.11 ] = -2.6914171937824483
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.00, -0.12 ] = -0.017025950811601798
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.05538332054068128
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06461604797583737
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.1395989060386963
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.13 ] = 0.0462851415558119
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.14457888563451754
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.14 ] = 0.12119383533379846
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 1]; reward: [ -0.00, -0.00, 0.40, -0.06, -0.12 ] = 0.21668230275511652
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13667960652518765
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05762279958044699
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.13 ] = -0.0717681295085274
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 1]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05909225395607654
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.01775118295360563
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.006372656731548243
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.23 ] = -0.008653768112209886
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05669277755638811
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.021370591289302493
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.016275144117570986
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.19 ] = 0.030359913070981515
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.013376002312681629
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.12 ] = 0.0979401975814184
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.14 ] = 0.08008686574217488
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 1]; reward: [ -2.80, -0.00, 0.40, -0.10, -0.08 ] = -2.5775441497448823
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.12 ] = -0.13667960652518765
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05877133994342703
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.07742417283754763
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.21 ] = -0.06531584871133131
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.14 ] = -0.07914899269171213
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02125404908692355
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.021726957281362633
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.10 ] = -2.683203129824468
# Action chosen:  change in topo of sub. 5 with switches [0, 1, 1, 1, 1] ; expected reward 0.2167
#  Simulation with no action; reward: [ -0.00, -0.00, 0.00, -0.06, -0.12 ] = -0.18279594267322774
#  Simulation with switching status of line 0; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0009620818821594879
#  Simulation with switching status of line 1; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.002881282802523477
#  Simulation with switching status of line 2; reward: [ -0.00, -0.00, 0.20, -0.06, -0.15 ] = -0.014721532504948537
#  Simulation with switching status of line 3; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0026323917265071717
#  Simulation with switching status of line 4; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.020054637804641992
#  Simulation with switching status of line 5; reward: [ -0.00, -0.00, 0.20, -0.06, -0.23 ] = -0.09155032801658092
#  Simulation with switching status of line 6; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.0011882794334161784
#  Simulation with switching status of line 7; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.01564321903030906
#  Simulation with switching status of line 8; reward: [ -0.00, -0.00, 0.20, -0.06, -0.15 ] = -0.0077651092485504225
#  Simulation with switching status of line 9; reward: [ -2.80, -0.00, 0.20, -0.06, -0.11 ] = -2.770794772099518
#  Simulation with switching status of line 10; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = 0.001680230048396708
#  Simulation with switching status of line 11; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.00954909861826167
#  Simulation with switching status of line 12; reward: [ -0.00, -0.00, 0.20, -0.06, -0.14 ] = -0.002146343552202723
#  Simulation with switching status of line 13; reward: [ -0.00, -1.40, 0.20, -0.06, -0.12 ] = -1.3827959426732277
#  Simulation with switching status of line 14; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.015643219030309338
#  Simulation with switching status of line 15; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.014030229648695464
#  Simulation with switching status of line 16; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.017060559415126214
#  Simulation with switching status of line 17; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.006544175646351125
#  Simulation with switching status of line 18; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.01580665197203622
# ...
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.10 ] = -0.11814023768086059
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.50 ] = -0.43519749875400565
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.72 ] = -0.6640522734717511
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 1]; reward: [ -2.80, -1.40, 0.20, -0.06, -0.65 ] = -4.706488021192252
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.04, -0.31 ] = -3.0467554392152856
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.55 ] = -0.4080378007916141
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.75 ] = -0.6100551290708004
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 1]; reward: [ -0.00, -1.40, 0.30, -0.08, -0.56 ] = -1.74066457488959
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.10 ] = -0.11814023768086059
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.11 ] = -0.04500875857429864
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.10 ] = -0.036509204625656634
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.037180364794268436
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.11 ] = -0.05201518719130497
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.04245560813442653
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.02290244421939125
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.09 ] = -2.67353178683955
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.00, -0.10 ] = 0.0015030892645733346
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.11 ] = 0.07341058087366761
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.10 ] = 0.08361471688343458
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.10 ] = 0.1564123733791698
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.11 ] = 0.06671044566653728
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.10 ] = 0.16367093102969948
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.12 ] = 0.144666835597431
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 1]; reward: [ -0.00, -0.00, 0.40, -0.06, -0.10 ] = 0.2390807438333229
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.10 ] = -0.11814023768086059
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.10 ] = -0.03871636428178261
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.11 ] = -0.04735669597733929
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 1]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.10 ] = -0.04251037041341083
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.036350949301915444
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.11 ] = 0.027555595658734472
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.18 ] = 0.03778375974947226
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.10 ] = -0.03794565915631124
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.038985585736786996
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.03567927156759018
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.15 ] = 0.0676904812732238
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.019042911632633983
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.11 ] = 0.11169430041904353
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.08, -0.12 ] = 0.09682863475182756
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 1]; reward: [ -2.80, -0.00, 0.40, -0.10, -0.07 ] = -2.5673531044550284
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.02, -0.10 ] = -0.11814023768086059
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.10 ] = -0.040383517417327035
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05927931307865351
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.19 ] = -0.04925051904828881
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.06487460839632647
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.03893555034903767
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.04105624097797968
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.08, -0.09 ] = -2.670516520876798
# Action chosen:  change in topo of sub. 5 with switches [0, 1, 1, 1, 1] ; expected reward 0.2391
#  Simulation with no action; reward: [ -0.00, -0.00, 0.00, -0.06, -0.10 ] = -0.163010886877068
#  Simulation with switching status of line 0; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.0169289323951861
#  Simulation with switching status of line 1; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.021258957209417825
#  Simulation with switching status of line 2; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.01784230957112988
#  Simulation with switching status of line 3; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.024198078542951598
#  Simulation with switching status of line 4; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.04010789581584939
#  Simulation with switching status of line 5; reward: [ -0.00, -0.00, 0.20, -0.06, -0.18 ] = -0.04082430765505468
#  Simulation with switching status of line 6; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.021070255231808846
#  Simulation with switching status of line 7; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.03589371461844702
#  Simulation with switching status of line 8; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.019465717017891918
#  Simulation with switching status of line 9; reward: [ -2.80, -0.00, 0.20, -0.06, -0.09 ] = -2.7538991734025973
#  Simulation with switching status of line 10; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.020942517122540416
#  Simulation with switching status of line 11; reward: [ -0.00, -0.00, 0.20, -0.06, -0.11 ] = 0.029539800441415368
#  Simulation with switching status of line 12; reward: [ -0.00, -0.00, 0.20, -0.06, -0.13 ] = 0.014589969278409609
#  Simulation with switching status of line 13; reward: [ -0.00, -1.40, 0.20, -0.06, -0.10 ] = -1.363010886877068
#  Simulation with switching status of line 14; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.03589371461844744
#  Simulation with switching status of line 15; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.03597933034232481
#  Simulation with switching status of line 16; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.036151796873580125
#  Simulation with switching status of line 17; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.023732777077883183
#  Simulation with switching status of line 18; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.03543831957172194
#  Simulation with switching status of line 19; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.0222145863442067
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.10 ] = -0.163010886877068
#  Simulation with change in topo of sub. 3 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.50 ] = -0.48405379914323876
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.76 ] = -0.7358764534215321
#  Simulation with change in topo of sub. 3 with switches [0, 0, 1, 1]; reward: [ -2.80, -1.40, 0.20, -0.10, -0.67 ] = -4.770644744346312
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.08, -0.42 ] = -3.204193789895513
#  Simulation with change in topo of sub. 3 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.61 ] = -0.5116546618409147
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.96 ] = -0.8623696530255897
#  Simulation with change in topo of sub. 3 with switches [0, 1, 1, 1]; reward: [ -0.00, -1.40, 0.30, -0.12, -0.78 ] = -2.0027351880488293
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.10 ] = -0.163010886877068
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.12 ] = -0.05891231343530486
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.10 ] = -0.03773408364158714
#  Simulation with change in topo of sub. 5 with switches [0, 0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.12 ] = 0.06303291402545651
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.04, -0.11 ] = -0.04573087253409342
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.10 ] = 0.08233557917339401
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.02, -0.11 ] = 0.07113667052051537
#  Simulation with change in topo of sub. 5 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.00, -0.10 ] = 0.19993357542794482
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 0]; reward: [ -2.80, -0.00, 0.10, -0.08, -0.09 ] = -2.874581306902224
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.12 ] = 0.020051211782664835
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.10 ] = 0.04104300229641952
#  Simulation with change in topo of sub. 5 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.11 ] = 0.14526812734537137
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 0]; reward: [ -0.00, -0.00, 0.20, -0.06, -0.11 ] = 0.0346002061397654
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.10 ] = 0.16234476778225987
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.04, -0.11 ] = 0.1522886352611142
#  Simulation with change in topo of sub. 5 with switches [0, 1, 1, 1, 1]; reward: [ -0.00, -0.00, 0.40, -0.02, -0.10 ] = 0.28042516113410176
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.10 ] = -0.163010886877068
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.10 ] = -0.08410628538155257
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.12 ] = -0.10053428298210809
#  Simulation with change in topo of sub. 9 with switches [0, 0, 0, 1, 1]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.10 ] = -0.08384820312641988
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.11 ] = -0.007412267275946308
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.12 ] = -0.018438660339543125
#  Simulation with change in topo of sub. 9 with switches [0, 0, 1, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.22 ] = -0.03584738225722367
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.10 ] = -0.08402066965767534
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.10 ] = -0.0036594548336654903
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.11 ] = -0.009396029497589012
#  Simulation with change in topo of sub. 9 with switches [0, 1, 0, 1, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.18 ] = 0.0022680287245161745
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 0]; reward: [ 0.00, 0.00, 0.20, -14.00, 0.00 ] = -13.8
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 0, 1]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.10 ] = 0.07618571226223611
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 0]; reward: [ -0.00, -0.00, 0.30, -0.12, -0.12 ] = 0.060053712240619464
#  Simulation with change in topo of sub. 9 with switches [0, 1, 1, 1, 1]; reward: [ -2.80, -0.00, 0.40, -0.14, -0.06 ] = -2.597097072995922
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 0]; reward: [ -0.00, -0.00, 0.00, -0.06, -0.10 ] = -0.163010886877068
#  Simulation with change in topo of sub. 13 with switches [0, 0, 0, 1]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.10 ] = -0.08456168042827784
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.12 ] = -0.09905748287745948
#  Simulation with change in topo of sub. 13 with switches [0, 0, 1, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.17 ] = -0.07109906287998116
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 0]; reward: [ -0.00, -0.00, 0.10, -0.08, -0.12 ] = -0.0977854136557933
#  Simulation with change in topo of sub. 13 with switches [0, 1, 0, 1]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.10 ] = -0.004060363756477087
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 0]; reward: [ -0.00, -0.00, 0.20, -0.10, -0.10 ] = -0.004959608889215733
#  Simulation with change in topo of sub. 13 with switches [0, 1, 1, 1]; reward: [ -2.80, -0.00, 0.30, -0.12, -0.08 ] = -2.7037506149338935
# Action chosen:  change in topo of sub. 5 with switches [0, 1, 1, 1, 1] ; expected reward 0.2804
# cumulative rewards : 7.279044999466738
# 47.73196887969971

# %%
import logging
import sys
import time
start = time.time()
NUMBER_ITERATIONS = 50 # The number of iterations can be changed

submission_dir = 'example_submission'
sys.path.append(submission_dir)

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
log_path = os.path.abspath(os.path.join(output_dir, 'runner.log'))


open(log_path, 'w').close()
submitted_controler = baseline_agents.TreeSearchLineServiceStatus(environment)
# Instanciate a runner, that will save the run statistics within the log_path file, to be parsed and processed
# by the scoring program
phase_runner = pypownet.runner.Runner(environment, submitted_controler, verbose=True, vverbose=False,
                                      log_filepath=log_path)
phase_runner.ch.setLevel(logging.ERROR)
# Run the planned experiment of this phase with the submitted model
score = phase_runner.loop(iterations=NUMBER_ITERATIONS)
print("cumulative rewards : {}".format(score))
end = time.time()
print(end-start)
